# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv(r"dataset_1 - dataset_1.csv")
df1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %%
df1.head(5)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        1  01-01-2011       1   0     1   0    False        6           1
# 1        2  01-01-2011       1   0     1   1    False        6           1
# 2        3  01-01-2011       1   0     1   2    False        6           1
# 3        4  01-01-2011       1   0     1   3    False        6           1
# 4        5  01-01-2011       1   0     1   4    False        6           1
#
#    temp
# 0  0.24
# 1  0.22
# 2  0.22
# 3  0.24
# 4  0.24

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    object
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), float64(1), int64(7), object(1)
# memory usage: 43.6+ KB

# %%
df1.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %%
df1.shape
# Out:
# (610, 10)

# %%
df1.isnull().values.any()
# Out:
# False

# %%
df1.plot()
# Out:
# <Axes: >

# %%
df1.plot(kind = 'line', title = 'weekday' , xlabel = 'temp' , ylabel = 'hour')
# Out:
# <Axes: title={'center': 'weekday'}, xlabel='temp', ylabel='hour'>

# %%
df2 = pd.read_csv(r"dataset_2.csv")
df2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered   cnt
# 0           0.0      1.0  0.2879  0.81        0.0     3.0        13.0  16.0
# 1           1.0      2.0  0.2727  0.80        0.0     8.0        32.0  40.0
# 2           2.0      3.0  0.2727  0.80        0.0     5.0        27.0  32.0
# 3           3.0      4.0  0.2879  0.75        0.0     3.0        10.0  13.0
# 4           4.0      5.0  0.2879  0.75        0.0     0.0         1.0   1.0
# ..          ...      ...     ...   ...        ...     ...         ...   ...
# 994         NaN      NaN     NaN   NaN        NaN     NaN         NaN   NaN
# 995         NaN      NaN     NaN   NaN        NaN     NaN         NaN   NaN
# 996         NaN      NaN     NaN   NaN        NaN     NaN         NaN   NaN
# 997         NaN      NaN     NaN   NaN        NaN     NaN         NaN   NaN
# 998         NaN      NaN     NaN   NaN        NaN     NaN         NaN   NaN
#
# [999 rows x 8 columns]

# %%
df2.head(5)
# Out:
#    Unnamed: 0  instant   atemp   hum  windspeed  casual  registered   cnt
# 0         0.0      1.0  0.2879  0.81        0.0     3.0        13.0  16.0
# 1         1.0      2.0  0.2727  0.80        0.0     8.0        32.0  40.0
# 2         2.0      3.0  0.2727  0.80        0.0     5.0        27.0  32.0
# 3         3.0      4.0  0.2879  0.75        0.0     3.0        10.0  13.0
# 4         4.0      5.0  0.2879  0.75        0.0     0.0         1.0   1.0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  610 non-null    float64
#  1   instant     610 non-null    float64
#  2   atemp       599 non-null    float64
#  3   hum         610 non-null    float64
#  4   windspeed   610 non-null    float64
#  5   casual      610 non-null    float64
#  6   registered  610 non-null    float64
#  7   cnt         610 non-null    float64
# dtypes: float64(8)
# memory usage: 62.6 KB

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0    389
# instant       389
# atemp         400
# hum           389
# windspeed     389
# casual        389
# registered    389
# cnt           389
# dtype: int64

# %%
df2.shape
# Out:
# (999, 8)

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2.plot(kind = 'line', title = 'weekday' , xlabel = 'temp' , ylabel = 'hour')
# Out:
# <Axes: title={'center': 'weekday'}, xlabel='temp', ylabel='hour'>

# %%
df1.merge(df2, how = 'inner', on = 'instant')
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
# ...

# %%
df1.merge(df2, how = 'outer')
# Out:
#      instant      dteday  season   yr  mnth   hr holiday  weekday  weathersit  \
# 0        1.0  01-01-2011     1.0  0.0   1.0  0.0   False      6.0         1.0
# 1        2.0  01-01-2011     1.0  0.0   1.0  1.0   False      6.0         1.0
# 2        3.0  01-01-2011     1.0  0.0   1.0  2.0   False      6.0         1.0
# 3        4.0  01-01-2011     1.0  0.0   1.0  3.0   False      6.0         1.0
# 4        5.0  01-01-2011     1.0  0.0   1.0  4.0   False      6.0         1.0
# ..       ...         ...     ...  ...   ...  ...     ...      ...         ...
# 994      NaN         NaN     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 995      NaN         NaN     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 996      NaN         NaN     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 997      NaN         NaN     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 998      NaN         NaN     NaN  NaN   NaN  NaN     NaN      NaN         NaN
#
# ...

# %%
df1.merge(df2, how = 'left')
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
# ...

# %%
df1.merge(df2, how = 'right')
# Out:
#      instant      dteday  season   yr  mnth   hr holiday  weekday  weathersit  \
# 0        1.0  01-01-2011     1.0  0.0   1.0  0.0   False      6.0         1.0
# 1        2.0  01-01-2011     1.0  0.0   1.0  1.0   False      6.0         1.0
# 2        3.0  01-01-2011     1.0  0.0   1.0  2.0   False      6.0         1.0
# 3        4.0  01-01-2011     1.0  0.0   1.0  3.0   False      6.0         1.0
# 4        5.0  01-01-2011     1.0  0.0   1.0  4.0   False      6.0         1.0
# ..       ...         ...     ...  ...   ...  ...     ...      ...         ...
# 994      NaN         NaN     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 995      NaN         NaN     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 996      NaN         NaN     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 997      NaN         NaN     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 998      NaN         NaN     NaN  NaN   NaN  NaN     NaN      NaN         NaN
#
# ...

# %%
df1.merge(df2, how = 'cross')
# Out:
#         instant_x      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0               1  01-01-2011       1   0     1   0    False        6
# 1               1  01-01-2011       1   0     1   0    False        6
# 2               1  01-01-2011       1   0     1   0    False        6
# 3               1  01-01-2011       1   0     1   0    False        6
# 4               1  01-01-2011       1   0     1   0    False        6
# ...           ...         ...     ...  ..   ...  ..      ...      ...
# 609385        610  28-01-2011       1   0     1  15    False        5
# 609386        610  28-01-2011       1   0     1  15    False        5
# 609387        610  28-01-2011       1   0     1  15    False        5
# 609388        610  28-01-2011       1   0     1  15    False        5
# 609389        610  28-01-2011       1   0     1  15    False        5
#
#         weathersit  temp  Unnamed: 0  instant_y   atemp   hum  windspeed  \
# ...

# %%
df1.join(df2, on = 'instant',how = 'outer',lsuffix ='_Left' ,rsuffix = '_Right')
# Out:
#      instant  instant_Left      dteday  season   yr  mnth   hr holiday  \
# NaN        0           NaN         NaN     NaN  NaN   NaN  NaN     NaN
# 0.0        1           1.0  01-01-2011     1.0  0.0   1.0  0.0   False
# 1.0        2           2.0  01-01-2011     1.0  0.0   1.0  1.0   False
# 2.0        3           3.0  01-01-2011     1.0  0.0   1.0  2.0   False
# 3.0        4           4.0  01-01-2011     1.0  0.0   1.0  3.0   False
# ..       ...           ...         ...     ...  ...   ...  ...     ...
# NaN      994           NaN         NaN     NaN  NaN   NaN  NaN     NaN
# NaN      995           NaN         NaN     NaN  NaN   NaN  NaN     NaN
# NaN      996           NaN         NaN     NaN  NaN   NaN  NaN     NaN
# NaN      997           NaN         NaN     NaN  NaN   NaN  NaN     NaN
# NaN      998           NaN         NaN     NaN  NaN   NaN  NaN     NaN
#
#      weekday  weathersit  temp  Unnamed: 0  instant_Right   atemp   hum  \
# ...

# %%
df4 = df1.set_index('instant').join(df2.set_index('instant'), lsuffix ='_Left' ,rsuffix = '_Right' ,how = 'outer')
df4
# Out:
#              dteday  season   yr  mnth   hr holiday  weekday  weathersit  \
# instant
# 1.0      01-01-2011     1.0  0.0   1.0  0.0   False      6.0         1.0
# 2.0      01-01-2011     1.0  0.0   1.0  1.0   False      6.0         1.0
# 3.0      01-01-2011     1.0  0.0   1.0  2.0   False      6.0         1.0
# 4.0      01-01-2011     1.0  0.0   1.0  3.0   False      6.0         1.0
# 5.0      01-01-2011     1.0  0.0   1.0  4.0   False      6.0         1.0
# ...             ...     ...  ...   ...  ...     ...      ...         ...
# NaN             NaN     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# NaN             NaN     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# NaN             NaN     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# NaN             NaN     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# NaN             NaN     NaN  NaN   NaN  NaN     NaN      NaN         NaN
#
#          temp  Unnamed: 0   atemp   hum  windspeed  casual  registered   cnt
# ...

# %%
pd.concat([df1,df2], join = 'outer' , axis = 1)
# Out:
#      instant      dteday  season   yr  mnth   hr holiday  weekday  weathersit  \
# 0        1.0  01-01-2011     1.0  0.0   1.0  0.0   False      6.0         1.0
# 1        2.0  01-01-2011     1.0  0.0   1.0  1.0   False      6.0         1.0
# 2        3.0  01-01-2011     1.0  0.0   1.0  2.0   False      6.0         1.0
# 3        4.0  01-01-2011     1.0  0.0   1.0  3.0   False      6.0         1.0
# 4        5.0  01-01-2011     1.0  0.0   1.0  4.0   False      6.0         1.0
# ..       ...         ...     ...  ...   ...  ...     ...      ...         ...
# 994      NaN         NaN     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 995      NaN         NaN     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 996      NaN         NaN     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 997      NaN         NaN     NaN  NaN   NaN  NaN     NaN      NaN         NaN
# 998      NaN         NaN     NaN  NaN   NaN  NaN     NaN      NaN         NaN
#
# ...
